# %%
# %matplotlib widget
import os
os.environ["GDAL_DATA"] = "/opt/homebrew/Caskroom/miniforge/base/envs/mygeo/share/gdal" # need to specify to make gdal work
os.environ["PROJ_LIB"] = "/opt/homebrew/Caskroom/miniforge/base/envs/mygeo/share/proj" # need to specify to make pyproj work
os.environ["PROJ_DATA"] = "/opt/homebrew/Caskroom/miniforge/base/envs/mygeo/share/proj" # need to specify to make pyproj work
import numpy as np
import pandas as pd
from matplotlib import cm 
import matplotlib
import matplotlib.pylab as plt
import geopandas as gpd
from ipyleaflet import Map, basemaps, Polygon, Polyline, GeoData, LayersControl, Marker
from datetime import datetime
from dateutil.relativedelta import relativedelta

from utils.nsidc import download_is2
from utils.readers import read_atl06
#from ed.edcreds import getedcreds
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Show area of interest on a map

# %%
# I just drew these randomly on a map...
shape = 'data/shapefiles/petermann_marginal_lake.geojson'
lake_small = 'data/shapefiles/petermann-small-lake.geojson'
shape_buffer = 'data/shapefiles/petermann_marginal_lake_buffer.geojson'

gdf = gpd.read_file(shape_buffer)
geom = [i for i in gdf.geometry]
lons,lats = geom[0].exterior.coords.xy
shape_buffer_coords = list(zip(lats,lons))
gdf = gpd.read_file(shape)
geom = [i for i in gdf.geometry]
lons,lats = geom[0].exterior.coords.xy
shape_coords = list(zip(lats,lons))
shape_bounds = [[np.min(lats),np.min(lons)], [np.max(lats),np.max(lons)]]
gdf = gpd.read_file(lake_small)
geom = [i for i in gdf.geometry]
lons,lats = geom[0].exterior.coords.xy
shape_small_lake_coords = list(zip(lats,lons))

m=Map(basemap=basemaps.Esri.WorldImagery,center=[np.mean(lats),np.mean(lons)],zoom=9)
m.fit_bounds(shape_bounds)
polygon = Polygon(locations=shape_buffer_coords, color="green", fill_color="blue", name='polygon_buffered')
m.add_layer(polygon)
polygon2 = Polygon(locations=shape_coords, color="blue", fill_color="blue", name='polygon')
m.add_layer(polygon2)
polygon3 = Polygon(locations=shape_small_lake_coords, color="red", fill_color="red", name='polygon')
m.add_layer(polygon3)
m.add_control(LayersControl())

### Include GNSS Site Coords
SCBY_coords = [80.26013264, -59.59361581]
SCBY = Marker(location=SCBY_coords, draggable=False)
m.add(SCBY)

m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[80.28435967005717, -59.58383610097026], controls=(ZoomControl(options=['position', 'zoom_in_text',…

# %% [markdown]
# ### Download the ICESat-2 data over this area

# %%
# this is just to get the earthdata credits into the notebook without pushing them to github
# can just specify them directly here like below
#uid = 'pchoi'
#pwd = '-'

#uid, pwd, email = getedcreds()

# to set up the getedcreds() function:
# - create a folder called "ed"
# - in this folder, create an empty file called "__init__.py"
# - in this folder, creat a file called "edcreds.py", with the following function:
#   def getedcreds(): return '<your_earthdata_user_id>', '<your_earthdata_password>', '<your_email_address>'
# - if you push to github, make sure to include the folder ed/ in your .gitignore
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### Data download 201 response error fix: loop through dates in 6-month increments

# %%
re_download_data = True

if re_download_data:

    # could change the version to 6 here, but there's more release 005 data so far
    version = 6

    start_download_date = '2018-06-30'
    short_name = 'ATL06'
    output_dir='data/IS2/v%03i' % version
    increment_months = 6

    dateformat = '%Y-%m-%d'
    end_download_datetime = datetime.strptime(start_download_date, dateformat)
    while end_download_datetime < datetime.now():
        start_download_datetime = end_download_datetime + relativedelta(days=1)
        end_download_datetime = start_download_datetime + relativedelta(months=increment_months)
        start_date = datetime.strftime(start_download_datetime, dateformat)
        end_date = datetime.strftime(end_download_datetime, dateformat)
        print('\n______________________________________________________________________\n')
        print('downloading data: %s  --->  %s' % (start_date, end_date))
        download_is2(short_name=short_name, 
                 start_date=start_date, 
                 end_date=end_date, 
                 uid=uid, 
                 pwd=pwd, 
                 shape=shape_buffer, 
                 output_dir=output_dir,
                 version=version)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ______________________________________________________________________
#
# downloading data: 2018-07-01  --->  2019-01-01
# Search parameters: {'short_name': 'ATL06', 'version': '006', 'temporal': '2018-07-01T00:00:00Z,2019-01-01T23:59:59Z', 'page_size': 100, 'page_num': 1, 'polygon': '-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425'}
#
# Found 18 ATL06 version 006 granules over the search area between 2018-07-01 and 2019-01-01.
#   ATL06_20181014081611_02400104_006_02.h5, 14.07 MB
#   ATL06_20181101175141_05210104_006_02.h5, 20.07 MB
#   ATL06_20181105174326_05820104_006_02.h5, 21.18 MB
#   ATL06_20181109173512_06430104_006_02.h5, 18.23 MB
#   ATL06_20181112065229_06820104_006_02.h5, 26.81 MB
#   ATL06_20181116064407_07430104_006_02.h5, 21.60 MB
#   ATL06_20181204161918_10240104_006_02.h5, 21.67 MB
#   ATL06_20181208161059_10850104_006_02.h5, 21.61 MB
#   ATL06_20181215051956_11850104_006_02.h5, 24.39 MB
#   ATL06_20181014081611_02400104_006_02.h5, 14.07 MB
#   and 8 more results...
#   --> There will be 1 total order(s) processed for our ATL06 request.
#
#
# https://n5eil02u.ecs.nsidc.org/egi/request?short_name=ATL06&version=006&temporal=2018-07-01T00:00:00Z,2019-01-01T23:59:59Z&Boundingshape=-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425&polygon=-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425&page_size=100&request_mode=stream&email=blah@ucsd.edu&page_num=1
#
# Order:  1
# Requesting...
# HTTP response from order response URL:  200
# Downloading...
# Data request 1 is complete.
#
# ______________________________________________________________________
#
# downloading data: 2019-01-02  --->  2019-07-02
# Search parameters: {'short_name': 'ATL06', 'version': '006', 'temporal': '2019-01-02T00:00:00Z,2019-07-02T23:59:59Z', 'page_size': 100, 'page_num': 1, 'polygon': '-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425'}
#
# Found 46 ATL06 version 006 granules over the search area between 2019-01-02 and 2019-07-02.
#   ATL06_20190102145527_00790204_006_02.h5, 21.03 MB
#   ATL06_20190106144706_01400204_006_02.h5, 19.79 MB
#   ATL06_20190117034735_03010204_006_02.h5, 27.11 MB
#   ATL06_20190131133137_05210204_006_02.h5, 21.54 MB
#   ATL06_20190204132319_05820204_006_02.h5, 21.44 MB
#   ATL06_20190208131458_06430204_006_02.h5, 21.64 MB
#   ATL06_20190211023213_06820204_006_02.h5, 26.38 MB
#   ATL06_20190305115919_10240204_006_02.h5, 9.98 MB
#   ATL06_20190309115058_10850204_006_02.h5, 19.38 MB
#   ATL06_20190312010815_11240204_006_02.h5, 26.63 MB
#   and 36 more results...
#   --> There will be 1 total order(s) processed for our ATL06 request.
#
#
# https://n5eil02u.ecs.nsidc.org/egi/request?short_name=ATL06&version=006&temporal=2019-01-02T00:00:00Z,2019-07-02T23:59:59Z&Boundingshape=-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425&polygon=-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425&page_size=100&request_mode=stream&email=blah@ucsd.edu&page_num=1
#
# Order:  1
# Requesting...
# HTTP response from order response URL:  200
# Downloading...
# Data request 1 is complete.
#
# ______________________________________________________________________
#
# downloading data: 2019-07-03  --->  2020-01-03
# Search parameters: {'short_name': 'ATL06', 'version': '006', 'temporal': '2019-07-03T00:00:00Z,2020-01-03T23:59:59Z', 'page_size': 100, 'page_num': 1, 'polygon': '-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425'}
#
# Found 48 ATL06 version 006 granules over the search area between 2019-07-03 and 2020-01-03.
#   ATL06_20190713191523_02400404_006_02.h5, 15.94 MB
#   ATL06_20190717190704_03010404_006_02.h5, 24.05 MB
#   ATL06_20190801045056_05210404_006_02.h5, 20.19 MB
#   ATL06_20190805044237_05820404_006_02.h5, 11.92 MB
#   ATL06_20190809043417_06430404_006_02.h5, 8.53 MB
#   ATL06_20190811175135_06820404_006_02.h5, 4.25 MB
#   ATL06_20190815174315_07430404_006_02.h5, 19.30 MB
#   ATL06_20190903031842_10240404_006_02.h5, 19.08 MB
#   ATL06_20190907031022_10850404_006_02.h5, 14.10 MB
#   ATL06_20190909162741_11240404_006_02.h5, 13.12 MB
#   and 38 more results...
#   --> There will be 1 total order(s) processed for our ATL06 request.
#
#
# https://n5eil02u.ecs.nsidc.org/egi/request?short_name=ATL06&version=006&temporal=2019-07-03T00:00:00Z,2020-01-03T23:59:59Z&Boundingshape=-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425&polygon=-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425&page_size=100&request_mode=stream&email=blah@ucsd.edu&page_num=1
#
# Order:  1
# Requesting...
# HTTP response from order response URL:  200
# Downloading...
# Data request 1 is complete.
#
# ______________________________________________________________________
#
# downloading data: 2020-01-04  --->  2020-07-04
# Search parameters: {'short_name': 'ATL06', 'version': '006', 'temporal': '2020-01-04T00:00:00Z,2020-07-04T23:59:59Z', 'page_size': 100, 'page_num': 1, 'polygon': '-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425'}
#
# Found 54 ATL06 version 006 granules over the search area between 2020-01-04 and 2020-07-04.
#   ATL06_20200104212613_01400604_006_01.h5, 21.32 MB
#   ATL06_20200107104331_01790604_006_01.h5, 26.32 MB
#   ATL06_20200111103511_02400604_006_01.h5, 26.62 MB
#   ATL06_20200129201037_05210604_006_01.h5, 21.21 MB
#   ATL06_20200202200216_05820604_006_01.h5, 21.36 MB
#   ATL06_20200206195354_06430604_006_01.h5, 22.18 MB
#   ATL06_20200209091112_06820604_006_01.h5, 22.05 MB
#   ATL06_20200213090252_07430604_006_01.h5, 11.80 MB
#   ATL06_20200302183815_10240604_006_01.h5, 22.33 MB
#   ATL06_20200306182956_10850604_006_01.h5, 22.16 MB
#   and 44 more results...
#   --> There will be 1 total order(s) processed for our ATL06 request.
#
#
# https://n5eil02u.ecs.nsidc.org/egi/request?short_name=ATL06&version=006&temporal=2020-01-04T00:00:00Z,2020-07-04T23:59:59Z&Boundingshape=-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425&polygon=-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425&page_size=100&request_mode=stream&email=blah@ucsd.edu&page_num=1
#
# Order:  1
# Requesting...
# HTTP response from order response URL:  200
# Downloading...
# Data request 1 is complete.
#
# ______________________________________________________________________
#
# downloading data: 2020-07-05  --->  2021-01-05
# Search parameters: {'short_name': 'ATL06', 'version': '006', 'temporal': '2020-07-05T00:00:00Z,2021-01-05T23:59:59Z', 'page_size': 100, 'page_num': 1, 'polygon': '-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425'}
#
# Found 52 ATL06 version 006 granules over the search area between 2020-07-05 and 2021-01-05.
#   ATL06_20200707020303_01790804_006_01.h5, 26.20 MB
#   ATL06_20200711015445_02400804_006_01.h5, 22.56 MB
#   ATL06_20200729113011_05210804_006_01.h5, 23.20 MB
#   ATL06_20200802112150_05820804_006_01.h5, 4.62 MB
#   ATL06_20200806111329_06430804_006_01.h5, 19.02 MB
#   ATL06_20200809003048_06820804_006_01.h5, 23.74 MB
#   ATL06_20200813002229_07430804_006_01.h5, 17.26 MB
#   ATL06_20200831095753_10240804_006_01.h5, 13.14 MB
#   ATL06_20200904094933_10850804_006_02.h5, 13.83 MB
#   ATL06_20200906230650_11240804_006_02.h5, 13.98 MB
#   and 42 more results...
#   --> There will be 1 total order(s) processed for our ATL06 request.
#
#
# https://n5eil02u.ecs.nsidc.org/egi/request?short_name=ATL06&version=006&temporal=2020-07-05T00:00:00Z,2021-01-05T23:59:59Z&Boundingshape=-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425&polygon=-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425&page_size=100&request_mode=stream&email=blah@ucsd.edu&page_num=1
#
# Order:  1
# Requesting...
# HTTP response from order response URL:  200
# Downloading...
# Data request 1 is complete.
#
# ______________________________________________________________________
#
# downloading data: 2021-01-06  --->  2021-07-06
# Search parameters: {'short_name': 'ATL06', 'version': '006', 'temporal': '2021-01-06T00:00:00Z,2021-07-06T23:59:59Z', 'page_size': 100, 'page_num': 1, 'polygon': '-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425'}
#
# Found 50 ATL06 version 006 granules over the search area between 2021-01-06 and 2021-07-06.
#   ATL06_20210108171427_02401004_006_01.h5, 24.74 MB
#   ATL06_20210127024953_05211004_006_01.h5, 22.30 MB
#   ATL06_20210131024134_05821004_006_01.h5, 22.14 MB
#   ATL06_20210204023314_06431004_006_01.h5, 19.90 MB
#   ATL06_20210206155033_06821004_006_01.h5, 20.70 MB
#   ATL06_20210301011734_10241004_006_01.h5, 17.08 MB
#   ATL06_20210305010917_10851004_006_01.h5, 7.57 MB
#   ATL06_20210307142635_11241004_006_01.h5, 18.87 MB
#   ATL06_20210311141815_11851004_006_01.h5, 27.45 MB
#   ATL06_20210329235340_00791104_006_01.h5, 17.55 MB
#   and 40 more results...
#   --> There will be 1 total order(s) processed for our ATL06 request.
#
#
# https://n5eil02u.ecs.nsidc.org/egi/request?short_name=ATL06&version=006&temporal=2021-01-06T00:00:00Z,2021-07-06T23:59:59Z&Boundingshape=-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425&polygon=-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425&page_size=100&request_mode=stream&email=blah@ucsd.edu&page_num=1
#
# Order:  1
# Requesting...
# HTTP response from order response URL:  200
# Downloading...
# Data request 1 is complete.
#
# ______________________________________________________________________
#
# downloading data: 2021-07-07  --->  2022-01-07
# Search parameters: {'short_name': 'ATL06', 'version': '006', 'temporal': '2021-07-07T00:00:00Z,2022-01-07T23:59:59Z', 'page_size': 100, 'page_num': 1, 'polygon': '-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425'}
#
# Found 50 ATL06 version 006 granules over the search area between 2021-07-07 and 2022-01-07.
#   ATL06_20210709083408_02401204_006_01.h5, 4.82 MB
#   ATL06_20210727180935_05211204_006_01.h5, 15.44 MB
#   ATL06_20210731180116_05821204_006_01.h5, 11.22 MB
#   ATL06_20210804175254_06431204_006_01.h5, 16.08 MB
#   ATL06_20210807071012_06821204_006_01.h5, 5.49 MB
#   ATL06_20210811070155_07431204_006_01.h5, 19.03 MB
#   ATL06_20210829163721_10241204_006_01.h5, 21.46 MB
#   ATL06_20210902162902_10851204_006_02.h5, 11.68 MB
#   ATL06_20210905054620_11241204_006_02.h5, 16.52 MB
#   ATL06_20210909053801_11851204_006_02.h5, 13.36 MB
#   and 40 more results...
#   --> There will be 1 total order(s) processed for our ATL06 request.
#
#
# https://n5eil02u.ecs.nsidc.org/egi/request?short_name=ATL06&version=006&temporal=2021-07-07T00:00:00Z,2022-01-07T23:59:59Z&Boundingshape=-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425&polygon=-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425&page_size=100&request_mode=stream&email=blah@ucsd.edu&page_num=1
#
# Order:  1
# Requesting...
# HTTP response from order response URL:  200
# Downloading...
# Data request 1 is complete.
#
# ______________________________________________________________________
#
# downloading data: 2022-01-08  --->  2022-07-08
# Search parameters: {'short_name': 'ATL06', 'version': '006', 'temporal': '2022-01-08T00:00:00Z,2022-07-08T23:59:59Z', 'page_size': 100, 'page_num': 1, 'polygon': '-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425'}
#
# Found 46 ATL06 version 006 granules over the search area between 2022-01-08 and 2022-07-08.
#   ATL06_20220125092925_05211404_006_01.h5, 21.06 MB
#   ATL06_20220202091244_06431404_006_01.h5, 22.15 MB
#   ATL06_20220204223002_06821404_006_01.h5, 26.15 MB
#   ATL06_20220208222142_07431404_006_01.h5, 16.78 MB
#   ATL06_20220227075710_10241404_006_01.h5, 16.03 MB
#   ATL06_20220303074848_10851404_006_01.h5, 19.61 MB
#   ATL06_20220305210608_11241404_006_01.h5, 21.55 MB
#   ATL06_20220309205748_11851404_006_01.h5, 21.38 MB
#   ATL06_20220328063315_00791504_006_01.h5, 21.85 MB
#   ATL06_20220401062453_01401504_006_02.h5, 21.96 MB
#   and 36 more results...
#   --> There will be 1 total order(s) processed for our ATL06 request.
#
#
# https://n5eil02u.ecs.nsidc.org/egi/request?short_name=ATL06&version=006&temporal=2022-01-08T00:00:00Z,2022-07-08T23:59:59Z&Boundingshape=-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425&polygon=-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425&page_size=100&request_mode=stream&email=blah@ucsd.edu&page_num=1
#
# Order:  1
# Requesting...
# HTTP response from order response URL:  200
# Downloading...
# Data request 1 is complete.
#
# ______________________________________________________________________
#
# downloading data: 2022-07-09  --->  2023-01-09
# Search parameters: {'short_name': 'ATL06', 'version': '006', 'temporal': '2022-07-09T00:00:00Z,2023-01-09T23:59:59Z', 'page_size': 100, 'page_num': 1, 'polygon': '-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425'}
#
# Found 48 ATL06 version 006 granules over the search area between 2022-07-09 and 2023-01-09.
#   ATL06_20220726004917_05211604_006_02.h5, 22.39 MB
#   ATL06_20220730004058_05821604_006_02.h5, 5.80 MB
#   ATL06_20220803003237_06431604_006_01.h5, 22.26 MB
#   ATL06_20220805134957_06821604_006_01.h5, 27.62 MB
#   ATL06_20220809134137_07431604_006_01.h5, 9.97 MB
#   ATL06_20220827231704_10241604_006_01.h5, 22.98 MB
#   ATL06_20220831230841_10851604_006_01.h5, 15.58 MB
#   ATL06_20220903122559_11241604_006_01.h5, 8.10 MB
#   ATL06_20220907121739_11851604_006_01.h5, 8.25 MB
#   ATL06_20220925215301_00791704_006_01.h5, 16.06 MB
#   and 38 more results...
#   --> There will be 1 total order(s) processed for our ATL06 request.
#
#
# https://n5eil02u.ecs.nsidc.org/egi/request?short_name=ATL06&version=006&temporal=2022-07-09T00:00:00Z,2023-01-09T23:59:59Z&Boundingshape=-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425&polygon=-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425&page_size=100&request_mode=stream&email=blah@ucsd.edu&page_num=1
#
# Order:  1
# Requesting...
# HTTP response from order response URL:  200
# Downloading...
# Data request 1 is complete.
#
# ______________________________________________________________________
#
# downloading data: 2023-01-10  --->  2023-07-10
# Search parameters: {'short_name': 'ATL06', 'version': '006', 'temporal': '2023-01-10T00:00:00Z,2023-07-10T23:59:59Z', 'page_size': 100, 'page_num': 1, 'polygon': '-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425'}
#
# Found 44 ATL06 version 006 granules over the search area between 2023-01-10 and 2023-07-10.
#   ATL06_20230123160845_05211804_006_02.h5, 21.49 MB
#   ATL06_20230131155207_06431804_006_02.h5, 20.95 MB
#   ATL06_20230203050926_06821804_006_02.h5, 25.64 MB
#   ATL06_20230301142808_10851804_006_02.h5, 15.72 MB
#   ATL06_20230304034531_11241804_006_02.h5, 26.79 MB
#   ATL06_20230326131237_00791904_006_02.h5, 22.99 MB
#   ATL06_20230330130413_01401904_006_02.h5, 23.00 MB
#   ATL06_20230402022127_01791904_006_02.h5, 27.24 MB
#   ATL06_20230406021320_02401904_006_02.h5, 27.42 MB
#   ATL06_20230424114832_05211904_006_02.h5, 23.17 MB
#   and 34 more results...
#   --> There will be 1 total order(s) processed for our ATL06 request.
#
#
# https://n5eil02u.ecs.nsidc.org/egi/request?short_name=ATL06&version=006&temporal=2023-01-10T00:00:00Z,2023-07-10T23:59:59Z&Boundingshape=-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425&polygon=-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425&page_size=100&request_mode=stream&email=blah@ucsd.edu&page_num=1
#
# Order:  1
# Requesting...
# HTTP response from order response URL:  200
# Downloading...
# Data request 1 is complete.
#
# ______________________________________________________________________
#
# downloading data: 2023-07-11  --->  2024-01-11
# Search parameters: {'short_name': 'ATL06', 'version': '006', 'temporal': '2023-07-11T00:00:00Z,2024-01-11T23:59:59Z', 'page_size': 100, 'page_num': 1, 'polygon': '-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425'}
#
# Found 48 ATL06 version 006 granules over the search area between 2023-07-11 and 2024-01-11.
#   ATL06_20230728071922_05822004_006_02.h5, 4.76 MB
#   ATL06_20230801071102_06432004_006_02.h5, 5.83 MB
#   ATL06_20230803202819_06822004_006_02.h5, 10.69 MB
#   ATL06_20230807201959_07432004_006_02.h5, 10.76 MB
#   ATL06_20230826055522_10242004_006_02.h5, 7.61 MB
#   ATL06_20230830054704_10852004_006_02.h5, 4.92 MB
#   ATL06_20230901190411_11242004_006_02.h5, 6.20 MB
#   ATL06_20230905185551_11852004_006_02.h5, 18.99 MB
#   ATL06_20230928042253_01402104_006_02.h5, 13.81 MB
#   ATL06_20230930174010_01792104_006_02.h5, 20.57 MB
#   and 38 more results...
#   --> There will be 1 total order(s) processed for our ATL06 request.
#
#
# https://n5eil02u.ecs.nsidc.org/egi/request?short_name=ATL06&version=006&temporal=2023-07-11T00:00:00Z,2024-01-11T23:59:59Z&Boundingshape=-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425&polygon=-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425&page_size=100&request_mode=stream&email=blah@ucsd.edu&page_num=1
#
# Order:  1
# Requesting...
# HTTP response from order response URL:  200
# Downloading...
# Data request 1 is complete.
#
# ______________________________________________________________________
#
# downloading data: 2024-01-12  --->  2024-07-12
# Search parameters: {'short_name': 'ATL06', 'version': '006', 'temporal': '2024-01-12T00:00:00Z,2024-07-12T23:59:59Z', 'page_size': 100, 'page_num': 1, 'polygon': '-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425'}
#
# Found 36 ATL06 version 006 granules over the search area between 2024-01-12 and 2024-07-12.
#   ATL06_20240121224649_05212204_006_01.h5, 21.22 MB
#   ATL06_20240125223828_05822204_006_01.h5, 21.12 MB
#   ATL06_20240129223009_06432204_006_01.h5, 20.19 MB
#   ATL06_20240201114726_06822204_006_01.h5, 16.96 MB
#   ATL06_20240205113909_07432204_006_01.h5, 25.04 MB
#   ATL06_20240223211423_10242204_006_01.h5, 18.36 MB
#   ATL06_20240227210602_10852204_006_01.h5, 21.19 MB
#   ATL06_20240301102318_11242204_006_01.h5, 25.27 MB
#   ATL06_20240305101503_11852204_006_01.h5, 27.12 MB
#   ATL06_20240323195014_00792304_006_01.h5, 22.38 MB
#   and 26 more results...
#   --> There will be 1 total order(s) processed for our ATL06 request.
#
#
# https://n5eil02u.ecs.nsidc.org/egi/request?short_name=ATL06&version=006&temporal=2024-01-12T00:00:00Z,2024-07-12T23:59:59Z&Boundingshape=-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425&polygon=-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425&page_size=100&request_mode=stream&email=blah@ucsd.edu&page_num=1
#
# Order:  1
# Requesting...
# HTTP response from order response URL:  200
# Downloading...
# Data request 1 is complete.
#
# ______________________________________________________________________
#
# downloading data: 2024-07-13  --->  2025-01-13
# Search parameters: {'short_name': 'ATL06', 'version': '006', 'temporal': '2024-07-13T00:00:00Z,2025-01-13T23:59:59Z', 'page_size': 100, 'page_num': 1, 'polygon': '-59.77843971828846,80.3801464054425,-60.108029562038446,80.35072706096496,-60.34423561672594,80.27957105284355,-60.481564718288446,80.20882960304722,-60.459592062038446,80.15262117884237,-60.349728780788446,80.13757838237139,-60.19042702297595,80.14698279424539,-60.053097921413446,80.19480735188164,-59.679562765163446,80.2628623805601,-59.48730202297595,80.27214848480153,-59.48730202297595,80.31475172081878,-59.77843971828846,80.3801464054425'}
#
# Found 0 ATL06 version 006 granules over the search area between 2024-07-13 and 2025-01-13.
# None
#   --> There will be 0 total order(s) processed for our ATL06 request.

# %%
# # if you want ATL03 data, you could run the code below
# download_is2(short_name='ATL03', 
#              start_date='2018-01-01', 
#              end_date='2030-01-01', 
#              uid=uid, 
#              pwd=pwd, 
#              shape=shape_buffer, 
#              output_dir='data/IS2')

# %% [markdown]
# ### Get a list of all the ATL06 data files over this region

# %%
search_for = 'ATL06_'
search_in = 'data/IS2/v%03i/' % version
filelist = [search_in+f for f in os.listdir(search_in) \
            if os.path.isfile(os.path.join(search_in, f)) & (search_for in f) & ('.h5' in f)]
# filelist.sort()
print('There are %i files.' % len(filelist))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# There are 228 files.

# %% [markdown]
# ### Just pick the first file, and plot the ground tracks on the map

# %%
print(filelist[0])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# data/IS2/v006/processed_ATL06_20191206225012_10850504_006_01.h5

# %%
file = filelist[0]
ancillary, dfs = read_atl06(file, verbose=False)
for gtx in dfs.keys():
    dfs[gtx] = dfs[gtx][dfs[gtx].qual_summary == 0]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### Some helpful ancillary data for an example ICESat-2 track

# %%
ancillary
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'granule_id': 'ATL06_20191206225012_10850504_006_01.h5',
#  'date': '2019-12-06',
#  'atlas_sdp_gps_epoch': 1198800018.0,
#  'rgt': 1085,
#  'cycle_number': 5,
#  'sc_orient': 'forward',
#  'gtx_beam_dict': {'gt1l': 6,
#   'gt1r': 5,
#   'gt2l': 4,
#   'gt2r': 3,
#   'gt3l': 2,
#   'gt3r': 1},
#  'gtx_strength_dict': {'gt1l': 'weak',
#   'gt1r': 'strong',
#   'gt2l': 'weak',
#   'gt2r': 'strong',
#   'gt3l': 'weak',
#   'gt3r': 'strong'}}

# %% [markdown]
# ### an example dataframe with ATL06 data

# %%
dfs[list(dfs.keys())[0]]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#        delta_time        lat        lon          xatc       yatc  dh_fit_dy  \
# 0    6.090781e+07  80.141987 -60.278091  8.954649e+06  41.037296  -0.041026
# 1    6.090781e+07  80.142162 -60.278315  8.954669e+06  41.035030  -0.044095
# 2    6.090781e+07  80.142337 -60.278540  8.954689e+06  41.075939  -0.052744
# 3    6.090781e+07  80.142512 -60.278766  8.954709e+06  41.114769  -0.072432
# 4    6.090781e+07  80.142687 -60.278992  8.954729e+06  41.164413  -0.083464
# ..            ...        ...        ...           ...        ...        ...
# 585  6.090782e+07  80.244363 -60.410204  8.966353e+06  39.837589  -0.239969
# 586  6.090782e+07  80.244538 -60.410432  8.966373e+06  39.830555  -0.249859
# 587  6.090782e+07  80.244713 -60.410660  8.966393e+06  39.823261  -0.229724
# 588  6.090782e+07  80.244888 -60.410888  8.966413e+06  39.816921  -0.217583
# 589  6.090782e+07  80.245063 -60.411116  8.966433e+06  39.815155  -0.237447
#
#               h    geoid_h  qual_summary
# 0    380.480621  18.428730             0
# 1    380.066193  18.427704             0
# 2    379.779694  18.426674             0
# 3    378.186340  18.425621             0
# 4    375.916748  18.424561             0
# ..          ...        ...           ...
# 585  290.975220  17.849707             0
# 586  291.838776  17.848841             0
# 587  295.167328  17.847958             0
# 588  298.078583  17.847071             0
# 589  298.246399  17.846203             0
#
# [590 rows x 9 columns]

# %% [markdown]
# ### show a few tracks on a map to get an idea of coverage

# %%
m=Map(basemap=basemaps.Esri.WorldImagery,center=[np.mean(lats),np.mean(lons)],zoom=9)
m.fit_bounds(shape_bounds)

# plot the first 15 tracks
nfiles = 50
filelist.sort()
for file in filelist[:nfiles]:
    ancillary, dfs = read_atl06(file, verbose=False)
    for gtx in dfs.keys():
        dfs[gtx] = dfs[gtx][dfs[gtx].qual_summary == 0]
        dfs[gtx].lat, dfs[gtx].lon
        coords = list(zip(dfs[gtx].lat, dfs[gtx].lon))
        weight = 2 if ancillary['gtx_strength_dict'][gtx] == 'strong' else 1
        name = 'track %d-%s' % (ancillary['rgt'], gtx)
        line = Polyline(locations=coords,color="red",weight=weight,fill=False, name=name)
        m.add_layer(line)

polygon = Polygon(locations=shape_coords, color="blue", fill_color="blue", name='polygon')
m.add_layer(polygon)

m.add_control(LayersControl())
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[80.28435967005717, -59.58383610097026], controls=(ZoomControl(options=['position', 'zoom_in_text',…

# %% [markdown]
# ### inspect some of the data

# %%
fig, ax = plt.subplots(figsize=[9, 5], dpi=100)
handles = []

# plot the first few files
nfiles = 10
colors = cm.cubehelix(np.linspace(0.05,0.9,nfiles))
for i, file in enumerate(filelist[:nfiles]):
    ancillary, dfs = read_atl06(file, verbose=False)
    df = pd.concat(dfs)
    df = df[df.qual_summary == 0].copy()
    df['h_geoid_corrected'] = df.h - df.geoid_h
    df = df[np.abs(df.h_geoid_corrected) < 1e5]
    ax.scatter(df.lat, df.h_geoid_corrected , s=1, alpha=0.3, color=tuple(colors[i,:]))
    scatt = ax.scatter(0, 0 , s=10, alpha=1, color=tuple(colors[i,:]), label=ancillary['date'])
    handles.append(scatt)
# ax.legend(loc='upper right')
plt.legend(handles=handles, bbox_to_anchor=(1.04, 0.5), loc="center left", borderaxespad=0, fontsize=6, ncols=2)
ax.set_xlim((80.12685987765869, 80.38980029579673))
ax.set_ylim((156.4133674621582, 634.9853904724121))
ax.set_xlabel('latitude')
ax.set_ylabel('elevation above geoid')
fig.tight_layout()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### get the lake elevation for each file

# %%
smoothing_length = 0.5  # length over which to smooth histogram in meters
min_elev = 130  # minimum elevation to consider in meters
max_elev = 280  # maximum elevation to consider in meters
dh = 0.01  # histogram bin spacing in meters

def lake_elev_time_series(lake_shape, files_directory):
    
    nfiles = None # put None to run for all files

    # make the list of all files to process
    search_for = 'ATL06_'
    search_in = files_directory
    filelist = [search_in+f for f in os.listdir(search_in) \
                if os.path.isfile(os.path.join(search_in, f)) & (search_for in f) & ('.h5' in f)]
    filelist.sort()

    gdf_lake = gpd.read_file(lake_shape)  # turn geojson shape into a georeferenced dataframe
    hist_bins = np.arange(min_elev, max_elev+dh, dh)
    hist_mids = hist_bins[:-1] + np.diff(hist_bins) / 2

    files_to_process = filelist[:nfiles]  # clip the filelist to the nfiles first entries
    date_list, elev_list, count_list = [], [], []  # initialize the output lists

    # loop through all the files
    for i, file in enumerate(files_to_process):

        # read the file
        ancillary, dfs = read_atl06(file, verbose=False)

        # get the date of the file
        this_date = datetime.strptime(ancillary['date'], '%Y-%m-%d')
        if len(dfs) > 0:  # make sure there is some data
            df = pd.concat(dfs,ignore_index=True)  # just throw all the beams together for this purpose
            df = df[df.qual_summary == 0].copy()  # take only data that passes the quality summary
            df['h_geoid_corrected'] = df.h - df.geoid_h  # correct surface heights for geoid elevation
            df = df[np.abs(df.h_geoid_corrected) < 1e5]  # remove weird large nodata values

            # turn this into a georeferenced dataframe and clip to the actual lake outline (at least roughly...)
            gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.lon, df.lat), crs="EPSG:4326")  
            gdf = gpd.clip(gdf, gdf_lake)

            # make a histogram of data point counts vs. elevations at get the elevation where most data falls
            counts, bins = np.histogram(gdf.h_geoid_corrected, bins=hist_bins)  # make the histogram
            window_size = int(np.ceil(smoothing_length/dh))  # get the window size for smoothing
            counts = pd.Series(counts).rolling(window=window_size, center=True).sum()  # smooth the data a bit (sum of counts over smoothing_length)
            max_counts = np.max(counts)  # how many counts do we get?

            # only use data with 5 points in a smoothing_length elevation window to make this more robust
            if max_counts > 10: 
                max_idx = np.argmax(counts)  # get the index of the histogram peak
                this_elev = hist_mids[max_idx]  # get the elevation where most data is found

                # append the results to the output lists
                date_list.append(this_date)
                elev_list.append(this_elev)
                count_list.append(max_counts)

        print('%i / %i files processed' % (i+1, len(files_to_process)), end='\r')
        
    results = pd.DataFrame({'date': date_list, 'elev': elev_list, 'counts': count_list})
    
    return results
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### put the results together and plot

# %%
lake_shape_main = 'data/shapefiles/petermann_marginal_lake.geojson'
lake_shape_small = 'data/shapefiles/petermann-small-lake.geojson'
files_directory = 'data/IS2/v006/'

results_main = lake_elev_time_series(lake_shape_main, files_directory)
results_small = lake_elev_time_series(lake_shape_small, files_directory)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 228 / 228 files processed

# %%
results_main = results_main[results_main.counts > 50]

fig, ax = plt.subplots(figsize=[8,5], dpi=100)

small_line, = ax.plot(results_small.date, results_small.elev, c='C1', lw=1, zorder=-1000, label='small lake')
main_line, = ax.plot(results_main.date, results_main.elev, c='C0', lw=1, zorder=-1000, label='main lake')

scatterplot = ax.scatter(results_main.date, results_main.elev, s=10, alpha=1, c=results_main.counts, cmap=cm.viridis_r, 
                   vmin=np.min(results_small.counts), vmax=500, zorder=1000, label='ATL06 lake elevation data points')
ax.scatter(results_small.date, results_small.elev, s=5, alpha=1, c=results_small.counts, cmap=cm.viridis_r, 
                   vmin=np.min(results_small.counts), vmax=500, zorder=1000, label='ATL06 lake elevation data points')

augusts = [datetime(2019, 8, 1) + relativedelta(years=i) for i in np.arange(5)]
yl = ax.get_ylim()
for aug1 in augusts:
    august_line, = ax.plot([aug1]*2, yl, 'r-', lw=0.5, label='August 1 of each year', zorder=-10000)

ax.set_xlabel('date')
ax.set_ylabel('lake elevation')
ax.set_title('Petermann Ice-Marginal Lake Elevation from ICESat-2 data')

# make colorbar
from mpl_toolkits.axes_grid1 import make_axes_locatable
# add the colorbar 
divider = make_axes_locatable(ax)
cax = divider.append_axes('right', size='4%', pad=0.05)
cbar = fig.colorbar(scatterplot, cax=cax, orientation='vertical')
cbar.ax.get_yaxis().labelpad = 10
cbar.ax.set_ylabel('ATL06 data point count within %g meters' % smoothing_length, rotation=270, fontsize=8)

ax.legend(handles=[small_line, main_line, scatterplot, august_line], loc='right', fontsize=8, scatterpoints=4)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
